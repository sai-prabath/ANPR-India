# %% [markdown]
# **Important!** : connect to ***T4*** GPU
#
#
# 1.   Click dropdown beside connect (upper right)
# 2.   Click change runtime type
# 3.   Select T4 GPU and save
#
# **Mount** Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# **Initialize** Root Directory

# %%
ROOT = '/content/gdrive/My Drive/ANPR-India'

# %% [markdown]
# **Install** Dependency

# %%
# !pip install ultralytics

# %% [markdown]
# **Train** the yolov8 model on your custom Dataset
#
# **Note :**
#
# *   Make sure the config.yaml is in correct location
# *   Make sure the paths are specified correctly

# %%
import os

from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

results = model.train(data=os.path.join(ROOT, "config.yaml"), epochs=25)  # train the model

# %% [markdown]
# **Save** result to **google drive**

# %%
# !scp -r /content/runs/detect/train '/content/gdrive/My Drive/ANPR-India'

# %% [markdown]
# ---
#
# -- Config.yaml -- Explaination
#
# ---
#
#
# path: '/content/gdrive/My Drive/ANPR-India' -> root directory
#
# train: images/train -> path to Training Images
#
# val: **val/train** -> path to validation images
#
# Note : **images/train** can be used instead **val/images** if you are using same images for both testing and validation
#
#
# names:
#
# 0: lc_plate
#
# ---
